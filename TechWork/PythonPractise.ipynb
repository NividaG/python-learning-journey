# %%
nums = [10, 20, 30]
nums.append(40)
print(nums[1])
# Out:
# 20

# %%
{'name': 'Nivida', 'city': 'Chandigarh', 'skills': ['iOS', 'Cloud', 'Android']}
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1

# %%
first_name = "Nivida"
last_name = "Suri"
age = "24"

full_name = first_name + " " + last_name
print(full_name)

# Modern way (recommended)
print(f"My name is {first_name} and I am {age} years old.")
# Out:
# Nivida Suri
# My name is Nivida and I am 24 years old.

# %%
age = 17

if age >= 18:
    print("You are a pro-programmer")
else:
    print("I am school going student")
# Out:
# I am school going studend

# %%
age = 0

if age < 18:
    print("You cannot vote")
elif age >=18:
    print("You can vote") 
elif age == 18:
    print("You can vote")
else:
 print("You cannot vote")
# Out:
# You cannot vote

# %%
age = 15
has_id = True

if age >= 18 and has_id:
    print("Entry allowed")
else:
    print("Entry not allowed")
# Out:
# Entry not allowed

# %%
Var_num = -10

if Var_num <=0:
    print("number is negative")
elif Var_num >=0:
    print("number is postive")
else:
    print("No positve no negative")
# Out:
# number is negative

# %%
Check_Numb = -4

if Check_Numb == 0:
    print("The number is zero")
elif Check_Numb > 0:
   if Check_Numb % 2 == 0:
     print("Positive is even")
   else:
      print("Positive is odd")
else:
   if Check_Numb % 2 == 0:
      print("Negative is even")
   else:
      print("Negaitve is odd")
# Out:
# Negative is even

# %%
person = {
    "name": "Alex",
    "age": 30,
    "is_developer": True,
    "city": "London"
}

print(person["name"])
print(person["age"])
print(person.get("city"))
print(person.get("salrary"))
# Out:
# Alex
# 30
# London
# None

# %%
book = {
    "book_title": "A book with title",
    "price": 200,
    "author": "Vienne Woods",
    "in_stock": True,
    }

book["price"] = 250
book["year"] = 2027
print(book["book_title"])
print(book["price"])
print(book.get("author"))
print(book.get("in_stock"))
print(book.get("year"))
print(book.get("publisher"))

new_book = book.copy()

print(new_book["price"])
new_book["book_title"] = "Marc Jacob"

print(book["book_title"])
print(new_book["book_title"])
# Out:
# A book with title
# 250
# Vienne Woods
# True
# 2027
# None
# 250
# A book with title
# Marc Jacob

# %%
def power(base, exp=2):
    return base ** exp

print(power(3))     # 9
print(power(3, 3))  # 27

# %%
def addTwoNumber(a, b):
    return a + b

print(addTwoNumber(3,4))
print(addTwoNumber(5,5))
# Out:
# 7
# 10

# %%
def apply_discount(price, discount_percent):
    return price - discount_percent/100

print(apply_discount(100, 10))
# Out:
# 99.9

# %%
def trimlowercase(text):
    return text.strip().lower()

print(trimlowercase("This year is auspcious"))
# Out:
# this year is auspcious

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def greet(self):
        return f"Hello, {self.name}"
